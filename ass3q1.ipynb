# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from google.colab import files
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-4ee8a8da-c39c-44ac-b905-fbde82c5ca78" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4ee8a8da-c39c-44ac-b905-fbde82c5ca78">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving mobile_cleaned-1549119762886_-452616671.csv to mobile_cleaned-1549119762886_-452616671.csv

# %%
data=pd.read_csv('mobile_cleaned-1549119762886_-452616671.csv')

# %%
data.isnull().sum()
# Out:
# sim_type                             0
# aperture                             0
# gpu_rank                             0
# weight                               1
# stand_by_time                        3
# processor_frequency                  0
# thickness                            0
# flash_type                           0
# front_camera_resolution              0
# auto_focus                           0
# screen_size                          0
# frames_per_second                    0
# FM                                   0
# no_of_reviews_in_gsmarena_in_week    2
# os                                   0
# phone_height                         1
# screen_protection                    0
# sim_size                             0
# price                                0
# talk_time                            1
# video_resolution                     1
# display_resolution                   0
# removable_battery                    0
# display_type                         0
# primary_camera_resolution            1
# battery_type                         0
# ram_memory                           0
# internal_memory                      0
# brand_rank                           0
# no_of_cores                          0
# micro_sd_slot                        0
# screen_pixel_density                 0
# water_proof_rate                     0
# phone_width                          0
# expandable_memory                    0
# version                              0
# usb_type                             0
# battery_capacity                     0
# processor_rank                       0
# is_liked                             0
# dtype: int64

# %%
data.describe()
# Out:
#          sim_type    aperture  ...  processor_rank    is_liked
# count  109.000000  109.000000  ...      109.000000  109.000000
# mean     0.981651    7.733945  ...       50.788991    0.844037
# std      1.347025    3.201973  ...       49.496366    0.364496
# min      0.000000    0.000000  ...        1.000000    0.000000
# 25%      0.000000    8.000000  ...       12.000000    1.000000
# 50%      0.000000    8.000000  ...       21.000000    1.000000
# 75%      3.000000   10.000000  ...       92.000000    1.000000
# max      4.000000   14.000000  ...      166.000000    1.000000
#
# [8 rows x 40 columns]

# %%
data.isnull().sum().sum()
# Out:
# 10

# %%
data['weight']=data['weight'].fillna(data['weight'].mean())
data['stand_by_time']=data['stand_by_time'].fillna(data['stand_by_time'].mean())
data['no_of_reviews_in_gsmarena_in_week']=data['no_of_reviews_in_gsmarena_in_week'].fillna(data['no_of_reviews_in_gsmarena_in_week'].mean())
data['phone_height']=data['phone_height'].fillna(data['phone_height'].mean())
data['talk_time']=data['talk_time'].fillna(data['talk_time'].mean())
data['video_resolution']=data['video_resolution'].fillna(data['video_resolution'].mean())
data['primary_camera_resolution']=data['primary_camera_resolution'].fillna(data['primary_camera_resolution'].mean())

# %%
data.isnull().sum()
# Out:
# sim_type                             0
# aperture                             0
# gpu_rank                             0
# weight                               0
# stand_by_time                        0
# processor_frequency                  0
# thickness                            0
# flash_type                           0
# front_camera_resolution              0
# auto_focus                           0
# screen_size                          0
# frames_per_second                    0
# FM                                   0
# no_of_reviews_in_gsmarena_in_week    0
# os                                   0
# phone_height                         0
# screen_protection                    0
# sim_size                             0
# price                                0
# talk_time                            0
# video_resolution                     0
# display_resolution                   0
# removable_battery                    0
# display_type                         0
# primary_camera_resolution            0
# battery_type                         0
# ram_memory                           0
# internal_memory                      0
# brand_rank                           0
# no_of_cores                          0
# micro_sd_slot                        0
# screen_pixel_density                 0
# water_proof_rate                     0
# phone_width                          0
# expandable_memory                    0
# version                              0
# usb_type                             0
# battery_capacity                     0
# processor_rank                       0
# is_liked                             0
# dtype: int64

# %%
data.isnull().sum().sum()
# Out:
# 0
